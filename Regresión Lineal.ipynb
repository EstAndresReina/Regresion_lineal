# %%
import matplotlib.pyplot as plt
from sklearn import linear_model # usando sklear para saber los valores optimos
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\eandr\\Desktop\\archive\\data1.csv", sep=",")

# %%
data
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
data.columns
data.info
data.describe
# Out:
# <bound method NDFrame.describe of    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500>

# %%
data.plot.scatter(x="metro", y="precio")
plt.show()

# %%
data.plot.scatter(x="precio", y="metro")
plt.show()

# %%
regresion = linear_model.LinearRegression()

# %%
years = data["metro"].values.reshape((-1,1))

# %%
modelo = regresion.fit(years, data["precio"])
print("Interseccion (b)", modelo.intercept_)
#imprimos la pendiente
print("Pendiente (m)", modelo.coef_)
# Out:
# Interseccion (b) 361.25714285714287
# Pendiente (m) [5.64571429]

# %%
entrada= [[2],[5],[10],[15],[20],[25],[30]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [372.54857143 389.48571429 417.71428571 445.94285714 474.17142857]

# %%
data.plot.scatter(x="metro", y="precio", label='Datos originales')
plt.scatter(entrada, predicciones, color='green')
plt.plot(entrada, predicciones, color='yellow', label='Línea de regresión')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()

# %%
entrada= [[2],[5],[10],[15],[20],[25],[30]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [372.54857143 389.48571429 417.71428571 445.94285714 474.17142857
#  502.4        530.62857143]

# %%
data.plot.scatter(x="metro", y="precio", label='Datos originales')
plt.scatter(entrada, predicciones, color='green')
plt.plot(entrada, predicciones, color='violet', label='Línea de regresión')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()

# %%
data.plot.scatter(x="metro", y="precio", label='Datos originales')
plt.scatter(entrada, predicciones, color='green')
plt.plot(entrada, predicciones, color='violet', label='Línea de regresión')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()
